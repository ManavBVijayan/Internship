# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Downloads/HRDataset_v14.csv')
pd.set_option('display.max_rows',None, "display.max_columns", None)
data
# Out:
#                  Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0          Adinolfi, Wilson  K  10026          0                0         1
# 1     Ait Sidi, Karthikeyan     10084          1                1         1
# 2            Akinkuolie, Sarah  10196          1                1         0
# 3                 Alagbe,Trina  10088          1                1         0
# 4             Anderson, Carol   10069          0                2         0
# 5            Anderson, Linda    10002          0                0         0
# 6              Andreola, Colby  10194          0                0         0
# 7                  Athwal, Sam  10062          0                4         1
# 8             Bachiochi, Linda  10114          0                0         0
# 9           Bacong, Alejandro   10250          0                2         1
# 10        Baczenski, Rachael    10252          1                1         0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
data.isna().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %%
data.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
data.shape
# Out:
# (311, 36)

# %%
corrmatrix = data.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(corrmatrix,vmin=0.4,vmax=0.9,annot=True,linewidths=0.2,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
#Relationship between EngagementSurvey and Salary
plt.figure(figsize=(10,6))
plt.figure(dpi=150)
plt.title("Relationship between EngagementSurvey and Salary")
sns.lineplot(x='EngagementSurvey',y='Salary', data=data)
# Out:
# <AxesSubplot:title={'center':'Relationship between EngagementSurvey and Salary'}, xlabel='EngagementSurvey', ylabel='Salary'>

# %%
#Relationship between SpecialProjectsCount and Salary
plt.figure(figsize=(10,6))
plt.figure(dpi=150)
plt.title("Relationship between SpecialProjectsCount and Salary")
sns.lineplot(x='SpecialProjectsCount',y='Salary', data=data)
# Out:
# <AxesSubplot:title={'center':'Relationship between SpecialProjectsCount and Salary'}, xlabel='SpecialProjectsCount', ylabel='Salary'>

# %%
#Relationship between gender and Salary
plt.figure(figsize=(10,6))
plt.figure(dpi=150)
plt.title("Relationship between gender and Salary")
sns.scatterplot(x='GenderID',y='Salary', data=data)
# Out:
# <AxesSubplot:title={'center':'Relationship between gender and Salary'}, xlabel='GenderID', ylabel='Salary'>

# %% [markdown]
# *Gender female has the highest salary

# %%
data.nlargest(1,['Salary'])
# Out:
#     Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  EmpStatusID  \
# 150   King, Janet  10089          1                1         0            1
#
#      DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  PositionID  \
# 150       2            3                       0  250000      0          16
#
#             Position State   Zip        DOB Sex MaritalDesc CitizenDesc  \
# 150  President & CEO    MA  1902  9/21/1954   F     Married  US Citizen
#
#     HispanicLatino RaceDesc DateofHire DateofTermination         TermReason  \
# 150            Yes    White   7/2/2012               NaN  N/A-StillEmployed
#
#     EmploymentStatus        Department         ManagerName  ManagerID  \
# 150           Active  Executive Office  Board of Directors        9.0
#
#     RecruitmentSource PerformanceScore  EngagementSurvey  EmpSatisfaction  \
# 150            Indeed      Fully Meets              4.83                3
#
# ...

# %% [markdown]
# * Employee King, Janet has the highest salary that is 250000

# %%
data.nsmallest(1,['Salary'])
# Out:
#      Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  EmpStatusID  \
# 310  Zima, Colleen  10271          0                4         0            1
#
#      DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  PositionID  \
# 310       5            3                       0   45046      0          19
#
#                     Position State   Zip        DOB Sex MaritalDesc  \
# 310  Production Technician I    MA  1730  8/17/1978   F     Widowed
#
#     CitizenDesc HispanicLatino RaceDesc DateofHire DateofTermination  \
# 310  US Citizen             No    Asian  9/29/2014               NaN
#
#             TermReason EmploymentStatus         Department    ManagerName  \
# 310  N/A-StillEmployed           Active  Production         David Stanley
#
#      ManagerID RecruitmentSource PerformanceScore  EngagementSurvey  \
# 310       14.0          LinkedIn      Fully Meets               4.5
#
#      EmpSatisfaction  SpecialProjectsCount LastPerformanceReview_Date  \
# ...

# %% [markdown]
# * Employee Zima, Colleen has the lowest salary that is 45046

# %%
#Number of Employees hired from each Platforms
data['RecruitmentSource'].value_counts()
# Out:
# Indeed                     87
# LinkedIn                   76
# Google Search              49
# Employee Referral          31
# Diversity Job Fair         29
# CareerBuilder              23
# Website                    13
# Other                       2
# On-line Web application     1
# Name: RecruitmentSource, dtype: int64

# %%
plt.figure(figsize = (18, 6))
plt.title("Number of Employees hired from each Platforms.")
plots=sns.countplot(x = "RecruitmentSource", data =data)
for p in plots.patches:
    plots.annotate(format(p.get_height()),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')

# %% [markdown]
# * Highest recruitment is from Indeed (87) platform and least is from On-line web application (1) platform

# %%
#Gender of employees 
print("Number_of_female=",list(data["GenderID"]).count(0))
print("Number_of_male=",list(data['GenderID']).count(1))
# Out:
# Number_of_female= 176
# Number_of_male= 135

# %%
data2=data[["Employee_Name","GenderID"]]

# %%
import warnings
warnings.filterwarnings('ignore')
data2['GenderID'] = data2['GenderID'].replace([0,1],['Female','Male'])
data2
# Out:
#                  Employee_Name GenderID
# 0          Adinolfi, Wilson  K     Male
# 1     Ait Sidi, Karthikeyan        Male
# 2            Akinkuolie, Sarah   Female
# 3                 Alagbe,Trina   Female
# 4             Anderson, Carol    Female
# 5            Anderson, Linda     Female
# 6              Andreola, Colby   Female
# 7                  Athwal, Sam     Male
# 8             Bachiochi, Linda   Female
# 9           Bacong, Alejandro      Male
# 10        Baczenski, Rachael     Female
# 11             Barbara, Thomas     Male
# 12            Barbossa, Hector     Male
# 13        Barone, Francesco  A     Male
# 14               Barton, Nader     Male
# 15               Bates, Norman     Male
# 16            Beak, Kimberly     Female
# 17         Beatrice, Courtney    Female
# 18               Becker, Renee   Female
# 19               Becker, Scott     Male
# 20             Bernstein, Sean     Male
# 21             Biden, Lowan  M   Female
# ...

# %%
plt.figure(figsize = (18, 6))
plt.title("Gender of employees")
plots=sns.countplot(x = "GenderID", data =data2)
for p in plots.patches:
    plots.annotate(format(p.get_height()),
                   (p.get_x() + p.get_width() / 2., p.get_height()),
                   ha='center', va='center',
                   xytext=(0, 9),
                   textcoords='offset points')

# %%
#marital status of employees
data['MaritalDesc'].value_counts()
# Out:
# Single       137
# Married      124
# Divorced      30
# Separated     12
# Widowed        8
# Name: MaritalDesc, dtype: int64

# %%
# Relationship between position and salary 
# here we check the average of salary of different positions
data1=data.groupby(["Position","PositionID"])['Salary'].mean().reset_index()
data1.rename(columns = {'Salary':'Avg Salary'}, inplace = True)
data1
# Out:
#                         Position  PositionID     Avg Salary
# 0                   Accountant I           1   63507.666667
# 1       Administrative Assistant           2   52280.000000
# 2             Area Sales Manager           3   64932.555556
# 3                   BI Developer           4   95465.000000
# 4                    BI Director           5  110929.000000
# 5                            CIO           6  220450.000000
# 6                   Data Analyst           9   89932.571429
# 7                  Data Analyst            9   88527.000000
# 8                 Data Architect           7  150290.000000
# 9         Database Administrator           8  108499.600000
# 10        Director of Operations          10  170500.000000
# 11             Director of Sales          11  180000.000000
# 12          Enterprise Architect          30  103613.000000
# 13                   IT Director          12  178000.000000
# 14               IT Manager - DB          13  144959.500000
# ...

# %%
plt.figure(figsize=(20,50))
plt.figure(dpi=150)
plt.title("Relationship between Position and Salary")
sns.barplot(x='Avg Salary',y='Position', data=data1)
sns.set(font_scale=.1)

# %%
data1.nlargest(1,['Avg Salary'])
# Out:
#            Position  PositionID  Avg Salary
# 19  President & CEO          16    250000.0

# %%
data1.nsmallest(1,['Avg Salary'])
# Out:
#                    Position  PositionID  Avg Salary
# 1  Administrative Assistant           2     52280.0

# %% [markdown]
# # Preprocessing

# %%
#checking the null values 
data.isna().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %% [markdown]
# * only Date of termination has the null values and we fill the null values

# %%
data['DateofTermination'].fillna('StillEmployed', inplace=True)

# %%
data.isna().sum()
# Out:
# Employee_Name                 0
# EmpID                         0
# MarriedID                     0
# MaritalStatusID               0
# GenderID                      0
# EmpStatusID                   0
# DeptID                        0
# PerfScoreID                   0
# FromDiversityJobFairID        0
# Salary                        0
# Termd                         0
# PositionID                    0
# Position                      0
# State                         0
# Zip                           0
# DOB                           0
# Sex                           0
# MaritalDesc                   0
# CitizenDesc                   0
# HispanicLatino                0
# RaceDesc                      0
# DateofHire                    0
# DateofTermination             0
# TermReason                    0
# EmploymentStatus              0
# Department                    0
# ManagerName                   0
# ManagerID                     8
# RecruitmentSource             0
# ...

# %%
#checking the outliers
numcols = data.dtypes[(data.dtypes=='int64') | (data.dtypes=='float64')].index

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for x in numcols:
    sns.boxplot(data[x],orient='h')
    plt.title(x)
    plt.show()

# %%
for x in numcols:
    print(x)
    descr = data[x].describe()
    IQR = descr['75%'] - descr['25%']
    upper_limit =  descr['75%'] + 1.5 * IQR
    lower_limit =  descr['25%'] - 1.5 * IQR  
    #outlier replacement
    data[x][data[x]>upper_limit] = upper_limit
    data[x][data[x]<lower_limit] = lower_limit
# Out:
# EmpID
# MarriedID
# MaritalStatusID
# GenderID
# EmpStatusID
# DeptID
# PerfScoreID
# FromDiversityJobFairID
# Salary
# Termd
# PositionID
# Zip
# ManagerID
# EngagementSurvey
# EmpSatisfaction
# SpecialProjectsCount
# DaysLateLast30
# Absences

# %%
for x in numcols:
    sns.boxplot(data[x],orient='h')
    plt.title(x)
    plt.show()

# %%
#label encoder 
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data['Employee_Name']  = le.fit_transform(data['Employee_Name'])
data['Position']  = le.fit_transform(data['Position'])
data['State']  = le.fit_transform(data['State'])
data['DOB']  = le.fit_transform(data['DOB'])
data['Sex']  = le.fit_transform(data['Sex'])
data['MaritalDesc']  = le.fit_transform(data['MaritalDesc'])
data['CitizenDesc']  = le.fit_transform(data['CitizenDesc'])
data['HispanicLatino']  = le.fit_transform(data['HispanicLatino'])
data['RaceDesc']  = le.fit_transform(data['RaceDesc'])
data['DateofHire']  = le.fit_transform(data['DateofHire'])
data['DateofTermination']  = le.fit_transform(data['DateofTermination'])
data['TermReason']  = le.fit_transform(data['TermReason'])
data['EmploymentStatus']  = le.fit_transform(data['EmploymentStatus'])
data['Department']  = le.fit_transform(data['Department'])
data['ManagerName']  = le.fit_transform(data['ManagerName'])
data['RecruitmentSource']  = le.fit_transform(data['RecruitmentSource'])
data['PerformanceScore']  = le.fit_transform(data['PerformanceScore'])
data['LastPerformanceReview_Date']  = le.fit_transform(data['LastPerformanceReview_Date'])
data.head()
# Out:
#    Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  EmpStatusID  \
# 0              0  10026          0              0.0         1            1
# 1              1  10084          1              1.0         1            5
# 2              2  10196          1              1.0         0            5
# 3              3  10088          1              1.0         0            1
# 4              4  10069          0              2.0         0            5
#
#    DeptID  PerfScoreID  FromDiversityJobFairID    Salary  Termd  PositionID  \
# 0       5            3                       0  62506.00      0          19
# 1       5            3                       0  96837.75      1          23
# 2       5            3                       0  64955.00      1          20
# 3       5            3                       0  64991.00      0          19
# 4       5            3                       0  50825.00      1          19
#
# ...

# %%
data=data.drop(['TermReason','DateofHire','DateofTermination','LastPerformanceReview_Date'],axis=1)

# %%
#min-max scaling
from sklearn import preprocessing
min_max=preprocessing.MinMaxScaler(feature_range=(0,1))
x=min_max.fit_transform(data)
x=pd.DataFrame(x)
x.describe()
# Out:
#                0           1           2           3           4           5   \
# count  311.000000  311.000000  311.000000  311.000000  311.000000  311.000000
# mean     0.500000    0.500000    0.398714    0.300965    0.434084    0.348071
# std      0.290072    0.290072    0.490423    0.315563    0.496435    0.448596
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.250000    0.250000    0.000000    0.000000    0.000000    0.000000
# 50%      0.500000    0.500000    0.000000    0.400000    0.000000    0.000000
# 75%      0.750000    0.750000    1.000000    0.400000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#           6      7      8           9           10          11          12  \
# count  311.0  311.0  311.0  311.000000  311.000000  311.000000  311.000000
# mean     0.0    0.0    0.0    0.404808    0.334405    0.441318    0.613318
# ...

# %%
#modelling
